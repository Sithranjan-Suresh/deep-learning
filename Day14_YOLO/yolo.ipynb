# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo26n.pt')
results = model("dog.jpg")
results[0].show()
# Out:
# image 1/1 /content/dog.jpg: 448x640 2 persons, 1 dog, 213.7ms
# Speed: 7.0ms preprocess, 213.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
result_truck = model('truck.jpg')
result_truck[0].show()
# Out:
# image 1/1 /content/truck.jpg: 320x640 3 cars, 3 trucks, 123.1ms
# Speed: 3.9ms preprocess, 123.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=2000x1000>
